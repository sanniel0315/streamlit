# %% [markdown]
# <a href="https://colab.research.google.com/github/sanniel0315/streamlit/blob/develop/tm_machine_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 76.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
from google.colab import files

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/saved_model/"
# Out:
# keras_model  keras_model.h5  labels.txt

# %%
import tensorflow as tf
h5_model_path = "/content/drive/MyDrive/Colab Notebooks/saved_model/keras_model.h5"
model = tf.keras.models.load_model(h5_model_path)

print("Teachable Machine `.h5` 模型成功載入！")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Teachable Machine `.h5` 模型成功載入！

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image

# 載入 Teachable Machine `.h5` 模型
model_path = "/content/drive/MyDrive/Colab Notebooks/saved_model/keras_model.h5"
model = tf.keras.models.load_model(model_path)

# 定義預測函數
def predict_image(image):
    image = image.resize((224, 224))  # 調整大小
    image = np.array(image) / 255.0   # 正規化
    input_data = np.expand_dims(image, axis=0)  # 增加 batch 維度

    predictions = model.predict(input_data)
    return {"預測結果": predictions.tolist()}

# 建立 Gradio 介面
iface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil"),
    outputs="json",
    title="Teachable Machine 預測器",
    description="上傳圖片並使用 Teachable Machine 模型進行預測",
)

# 啟動 Web App
iface.launch(share=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://92fbd59cc3855141e2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://92fbd59cc3855141e2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
